# %% [raw]
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns
# from sklearn.model_selection import train_test_split
# from sklearn.preprocessing import StandardScaler
# from sklearn import svm
# from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data Collection, Analysis and Pre-Processing

# %%
parkinsons_data = pd.read_csv(r"C:\Users\pande\OneDrive\Desktop\parkinson_disease_detection_svm\data\parkinsons.csv")

# %%
parkinsons_data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
parkinsons_data.shape
# Out:
# (195, 24)

# %%
parkinsons_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
# checking for missing values in each column
parkinsons_data.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
parkinsons_data.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
# distribution of target(Y) Variable
parkinsons_data['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %% [markdown]
# * 1 -> Parkinson's Positive
# * 0 -> Not Parkinson Positive

# %%
# grouping the data based on the target variable
parkinsons_data.groupby('status').mean(numeric_only=True)
# Out:
#         MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# status
# 0        181.937771    223.636750    145.207292        0.003866
# 1        145.180762    188.441463    106.893558        0.006989
#
#         MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# status
# 0               0.000023  0.001925  0.002056    0.005776      0.017615
# 1               0.000051  0.003757  0.003900    0.011273      0.033658
#
#         MDVP:Shimmer(dB)  ...  MDVP:APQ  Shimmer:DDA       NHR        HNR  \
# status                    ...
# 0               0.162958  ...  0.013305     0.028511  0.011483  24.678750
# 1               0.321204  ...  0.027600     0.053027  0.029211  20.974048
#
#             RPDE       DFA   spread1   spread2        D2       PPE
# status
# 0       0.442552  0.695716 -6.759264  0.160292  2.154491  0.123017
# 1       0.516816  0.725408 -5.333420  0.248133  2.456058  0.233828
#
# [2 rows x 22 columns]

# %%
# separating features and target
X = parkinsons_data.drop(columns=['name','status'], axis=1)
Y = parkinsons_data['status']

# %%
print(X)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %%
# splitting the data to training data and test data
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %% [markdown]
# ## Data Standardization

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
#mmc
mmc=MinMaxScaler(feature_range = (0,1))

# %%
X_train_trans=mmc.fit_transform(X_train)
X_test_trans=mmc.transform(X_test)

# %%
print(X_train)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 123      182.018       197.173        79.187         0.00842
# 160      114.238       124.393        77.022         0.00581
# 94       157.821       172.975        68.401         0.00358
# 57       117.274       129.916       110.402         0.00752
# 41       184.055       196.537       166.977         0.00258
# ..           ...           ...           ...             ...
# 43       241.404       248.834       232.483         0.00281
# 22       167.930       193.221        79.068         0.00442
# 72       120.080       139.710       111.208         0.00405
# 15       142.167       217.455        83.159         0.00369
# 168      197.569       217.627        90.794         0.00803
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 123           0.00005   0.00506   0.00449     0.01517       0.02503
# 160           0.00005   0.00299   0.00316     0.00896       0.04009
# ...

# %% [markdown]
# ## Model Training

# %%
model = svm.SVC(kernel='linear')

# %%
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# ## Model Evaluation

# %%
# Accuracy score

# accuracy score on training data

X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(Y_train, X_train_prediction)

# %%
print('Accuracy score of training data : ', training_data_accuracy)
# Out:
# Accuracy score of training data :  0.8717948717948718

# %%
# accuracy score on testing data

X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(Y_test, X_test_prediction)

# %%
print('Accuracy score of test data : ', test_data_accuracy)
# Out:
# Accuracy score of test data :  0.8717948717948718

# %% [markdown]
# ## Classification report

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
print(classification_report(Y_test, X_test_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.50      0.62         8
#            1       0.88      0.97      0.92        31
#
#     accuracy                           0.87        39
#    macro avg       0.84      0.73      0.77        39
# weighted avg       0.87      0.87      0.86        39

# %% [markdown]
# ## confusion matrix

# %%
matrix = confusion_matrix(Y_test, X_test_prediction)

# %%
matrix
# Out:
# array([[ 4,  4],
#        [ 1, 30]], dtype=int64)

# %%
# heatmap
sns.heatmap(data=matrix, annot=True, fmt='g')
plt.title("SVM Classifier")
plt.show()

# %%
def get_details():
    print("Model Type:", type(model).__name__)
    print("\nModel Parameters:\n", model.get_params())
    print("\nPerformance Metrics:")
    print("Accuracy:", accuracy_score(Y_test, X_test_prediction))
    print("\nConfusion Matrix:\n", confusion_matrix(Y_test, X_test_prediction))
    print("\nClassification Report:\n", classification_report(Y_test, X_test_prediction))

# %%
get_details()
# Out:
# Model Type: SVC
#
# Model Parameters:
#  {'C': 1.0, 'break_ties': False, 'cache_size': 200, 'class_weight': None, 'coef0': 0.0, 'decision_function_shape': 'ovr', 'degree': 3, 'gamma': 'scale', 'kernel': 'linear', 'max_iter': -1, 'probability': False, 'random_state': None, 'shrinking': True, 'tol': 0.001, 'verbose': False}
#
# Performance Metrics:
# Accuracy: 0.8717948717948718
#
# Confusion Matrix:
#  [[ 4  4]
#  [ 1 30]]
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.50      0.62         8
#            1       0.88      0.97      0.92        31
#
#     accuracy                           0.87        39
#    macro avg       0.84      0.73      0.77        39
# weighted avg       0.87      0.87      0.86        39

# %% [markdown]
# # Building a Predictive System

# %%
input_data = (196.07600,200.89600,192.45500,0.00289,0.00007,0.00266,0.00178,0.00498,0.01098,0.09700,0.00563,0.00680,0.00802,0.01689,0.00339,26.77500,0.422229,0.741367,-7.348300,0.177551,1.743867,0.085569)

# changing input data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the numpy array
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardize the data
std_data = mmc.transform(input_data_reshaped)

prediction = model.predict(std_data)
print(prediction)


if (prediction[0] == 0):
  print("The Person does not have Parkinson's Disease")

else:
  print("The Person has Parkinson's Disease")
# Out:
# [1]
# The Person has Parkinson's Disease
# C:\Users\pande\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# C:\Users\pande\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
import pickle
with open("Model_Prediction.sav", "wb") as f:
    pickle.dump(model,f)

# %%
with open("MinMaxScaler.sav", "wb") as f:
    pickle.dump(mmc,f)
